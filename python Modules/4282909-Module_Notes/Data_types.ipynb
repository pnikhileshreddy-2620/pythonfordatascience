# %% [markdown]
# ## **Data types**
# * Integers (int)
# * Floating point numbers (float)
# * String (str)
# * Boolean types

# %%
# Integers
a = 3
b = -450
c = 21549873 ** 100
print(c)

# %%
a = 516

# %%
a = 516 ** 100
print(a)
# Out:
# 

# %%
# Floating-Point numbers
# Range: -10^308 to 10^308; 16 digits of precision
a = 3.14
b = -689.53

# Scientific notation
c = 4e2 # 4 * 10 * 10 
d = 3.78e3
print(d)
f = -78.0e6
print(f)

# %%
a = 5.3
b = 2.7

# %%
a = 5.31478421369874512

# %%
# Strings
"Hello World!"
'Hello World!'
"It's my class"

a = ''
b = ' '
c = "This very long sentence. It is in the same line"
print(c)
d = """My name is Vinay.
I teach python.
I work at OdinSchool"""
print(d)

# %%
a = ""
print(a)

# %%
c = "     "
print(c)
# Out:
# '   '

# %%
"Hello all"
# Out:
# 'Hello all'

# %%
"124@#  56"
# Out:
# '124@#  56'

# %%
c = """This very long sentence. It is in the same line
Hi Hello
Bye"""
print(c)
# Out:
# This very long sentence. It is in the same line
# Hi Hello
# Bye

# %%
d = """My name is Vinay.
I teach python.
I work at OdinSchool"""
print(d)
# Out:
# My name is Vinay.
# I teach python.
# I work at OdinSchool

# %%
# Boolean 
a = True

# %%
b = False

# %%
# All procedural programming -> Case sensitive(Python, C, C++, Java)
# All non-procedural languages -> Case insensitive (Sql, html)

# %% [markdown]
# ### **Type conversion**

# %%
a = 3

# %%
a = input("Enter the value of a: ")
b = input("Enter the value of b: ")
# Out:
# Enter the value of a: 3
# Enter the value of b: 4

# %%
print(a+b)
# Out:
# 34

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# str

# %%
"3" + "4"
# Out:
# '34'

# %%
a = input("Enter the value of a: ")
b = input("Enter the value of b: ")

a = int(a)
b = int(b)
# Out:
# Enter the value of a: 3
# Enter the value of b: 4
# int

# %%
print(a+b)
# Out:
# 7

# %%
a = int(input("Enter the value of a: "))
# Out:
# Enter the value of a: 5

# %%
a = 3.14
type(a)
# Out:
# float

# %% [markdown]
# ### **Practice problems**
# 1. WAP to find the sum, difference, product and true division of two integers.
# 2. WAP to find the area of a rectangle.
# 3. WAP that takes three numbers as input to calculate and print the average of the numbers.

# %%
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

area = length * width
print(area)
# Out:
# Enter the length of the rectangle: 2.5
# Enter the width of the rectangle: 8.3
# 20.75

# %%
a = float(input("Enter the value of a: "))
b = float(input("Enter the value of b: "))
c = a + b
print(c)
# Out:
# Enter the value of a: 3
# Enter the value of b: 4
# 7

# %%
a = 7
a = 5
a = 3
a = 4
print(a)
# Out:
# 4

# %%
a = 3
b = 4
c = 7

avg = (a+b+c) / 3
print("The average of three numbers is ", avg)
# Out:
# The average of three numbers is  4.666666666666667

# %% [markdown]
# ## **Math module**
# * Functions
# * Constants

# %%
import math

# %%
help(math)

# %%
dir(math)

# %%
# Functions
# 1. factorial()
# 2. ceil(), floor()
# 3. pow()
# 4. sqrt()

# %%
math.factorial(5)
# Out:
# 120

# %%
round(5.73654)
# Out:
# 6

# %%
math.ceil(5.001)
# Out:
# 6

# %%
math.floor(7.99)
# Out:
# 7

# %%
3 ** 3
# Out:
# 27

# %%
math.pow(3, 2)
# Out:
# 9.0

# %%
a = math.sqrt(25)
print(a)
# Out:
# 5.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import math
radius = 5

area = math.pi * math.pow(radius, 2)
print(area)

# %% [markdown]
# ### Practice problems
# 1. WAP to find the area of a circle.
# 2. WAP to calculate volume and surface area of a cylinder.
# * Inputs: radius and height
#
# * Output: Volume = pi * (r ** 2) * h and Surface area = 2 * pi * r * h + 2 * pi * r ** 2

# %%
radius = 5
height = 10
volume = math.pi * (radius ** 2) * height
print(volume)
# Out:
# 785.3981633974483

# %%
3 + 4
